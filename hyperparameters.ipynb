# %% [markdown]
# # Hyperparameters
#
# This notebook shows the results of the studies made for different hyperparameters.

# %%
import main as mn
import paint as pt

# %% [markdown]
# ## Checking one study

# %%
model,history,l,x_train,x_validation,x_test,y_train,y_validation,y_test=mn.load_model(route='pre-trained/activation',key='sigmoid')
mn.error_model(model,x_train,x_validation,x_test,y_train,y_validation,y_test)
# Out:
# 3/3 [==============================] - 1s 2ms/step - loss: 4.3570e-04 - mae: 0.0106
# [0.00043570081470534205, 0.01058456115424633]
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0019 - mae: 0.0183
# [0.0019345622276887298, 0.018293514847755432]
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0010 - mae: 0.0142
# [0.0010194247588515282, 0.014228704385459423]

# %% [markdown]
# ## Comparation

# %% [markdown]
# ### Activation Function

# %%
pt.paint_training('pre-trained/activation',['softmax','relu','softplus','softsign','tanh','sigmoid'])

# %% [markdown]
# ### Optimizer

# %%
pt.paint_training('pre-trained/optimizer',['SGD','Adagrad','RMSprop','Nadam','Adam'])

# %% [markdown]
# ### Learning Rate

# %%
pt.paint_training('pre-trained/learning',['8e-4','5e-4','1e-4','8e-5','5e-5','3e-5'])

# %% [markdown]
# ### Batch Size

# %%
pt.paint_training('pre-trained/batch',['20','40','60','80'])

# %% [markdown]
# ### Number of hidden layers

# %%
pt.paint_training('pre-trained/layers',['1','2','3','4','5'])

# %% [markdown]
# ### Number of neurons per hidden layer

# %%
pt.paint_training('pre-trained/neurons',['150','200','250'])

# %% [markdown]
# ### Size of data set

# %%
pt.paint_training('pre-trained/trainingsize',['50','100','200','400'])
